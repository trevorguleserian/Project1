# %%
import pandas as pd

# %%
movies_csv = '../Resources/movies.csv.zip'
movies_df = pd.read_csv(movies_csv)
movies_df = movies_df[['Title', 'Year', 'IMDb','Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Directors']]
movies_df
# Out:
#                                 Title  Year  IMDb  Netflix  Hulu  Prime Video  \
# 0                           Inception  2010   8.8        1     0            0
# 1                          The Matrix  1999   8.7        1     0            0
# 2              Avengers: Infinity War  2018   8.5        1     0            0
# 3                  Back to the Future  1985   8.5        1     0            0
# 4      The Good, the Bad and the Ugly  1966   8.8        1     0            1
# ...                               ...   ...   ...      ...   ...          ...
# 16739       The Ghosts of Buxley Hall  1980   6.2        0     0            0
# 16740                  The Poof Point  2001   4.7        0     0            0
# 16741           Sharks of Lost Island  2013   5.7        0     0            0
# 16742              Man Among Cheetahs  2017   6.6        0     0            0
# 16743                In Beaver Valley  1950   NaN        0     0            0
#
# ...

# %%
clean_movies_df = movies_df.dropna(how='any').reset_index()
clean_movies_df
# Out:
#        index                           Title  Year  IMDb  Netflix  Hulu  \
# 0          0                       Inception  2010   8.8        1     0
# 1          1                      The Matrix  1999   8.7        1     0
# 2          2          Avengers: Infinity War  2018   8.5        1     0
# 3          3              Back to the Future  1985   8.5        1     0
# 4          4  The Good, the Bad and the Ugly  1966   8.8        1     0
# ...      ...                             ...   ...   ...      ...   ...
# 15685  16738    Whispers: An Elephant's Tale  2000   5.0        0     0
# 15686  16739       The Ghosts of Buxley Hall  1980   6.2        0     0
# 15687  16740                  The Poof Point  2001   4.7        0     0
# 15688  16741           Sharks of Lost Island  2013   5.7        0     0
# 15689  16742              Man Among Cheetahs  2017   6.6        0     0
#
#        Prime Video  Disney+                       Directors
# ...

# %%
clean_movies_df.to_csv('clean_movies.csv', index=False, header=True)
